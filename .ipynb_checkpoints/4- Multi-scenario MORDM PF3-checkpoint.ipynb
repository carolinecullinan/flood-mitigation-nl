# %% [markdown]
# # Introduction
#
# In this notebook, we used a multi-scenario multi-objective robust decision-making (MSMORDM) approach to perform a directed  search for optimal policies and subsequently evaluate for robustness. MSMORDM can be used to search for candidate policy alternatives using many objective evolutionary algorithms (MOEAs) for several reference scenarios (Bartholomew & Kwakkel, 2020). This notebook applies MS-MORDM to Problem Formulation 1, while notebook 4- Multi-scenario MORDM PF3.ipynb contains the analysis for Problem Formulation 3.
#
# The worst case scenario identified in the open explanation has been used as a reference scenario to perform MORDM.
#
# ## 0.0 Import libraries

# %%
from ema_workbench import (Model, RealParameter, ScalarOutcome, CategoricalParameter, IntegerParameter,
                           SequentialEvaluator, MultiprocessingEvaluator, ema_logging,
                           Policy, Constant, Scenario, Constraint, save_results, load_results)
from ema_workbench.analysis import parcoords, prim
from ema_workbench.em_framework import optimization
from ema_workbench.em_framework.samplers import sample_uncertainties
from ema_workbench.em_framework.evaluators import BaseEvaluator
from ema_workbench.em_framework.optimization import (HyperVolume, EpsilonProgress)
ema_logging.log_to_stderr(ema_logging.INFO)

from problem_formulation import get_model_for_problem_formulation

import pandas as pd
import numpy as np
import time
import matplotlib
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 1.0 Experimental Set-up
# First, we select Problem Formulation 1, which yields 3 outcomes:
# * Expected Annual Damage
# * Total Investment Costs
# * Expected Number of Deaths

# %%
model, steps = get_model_for_problem_formulation(3)

# %% [markdown]
# Getting lists of model uncertainties, levers, and outcomes.

# %%
model_uncertainties = []
for i in model.uncertainties:
    model_uncertainties.append(i.name)

# %%
model_levers = []
for i in model.levers:
    model_levers.append(i.name)

# %%
model_outcomes = []
for i in model.outcomes:
    model_outcomes.append(i.name)

# %% [markdown]
# ### Step 1: Searching for optimized levers given 1 reference scenario.
# In this case, the reference scenario was selected from the open exploration process; it was the scenario that yielded the worst outcomes for in terms of Expected Number of Deaths.

# %%
reference = Scenario(**{'discount rate 0': 1.5, 'discount rate 1': 1.5, 'discount rate 2': 1.5,
                        'A.0_ID flood wave shape': 43.0, 'A.1_Bmax': 53.423569949295526,
                        'A.1_pfail': 0.20428240393608074, 'A.1_Brate': 10,
                        'A.2_Bmax': 267.3434506622656, 'A.2_pfail': 0.1804622034784221,
                        'A.2_Brate': 10, 'A.3_Bmax': 320.9123978280144,
                        'A.3_pfail': 0.028493206036833557, 'A.3_Brate': 1.5,
                        'A.4_Bmax': 283.8695071143246, 'A.4_pfail': 0.4432843146318262,
                        'A.4_Brate': 1.0, 'A.5_Bmax': 53.52141321453644, 
                        'A.5_pfail': 0.9576930156260828, 'A.5_Brate': 1.5})

# %%
convergence = [EpsilonProgress()]
epsilons = [0.75e7, 0.05]*5
epsilons.append(0.75e8)
epsilons.append(80)

# %%
# starttime = time.time()

# with MultiprocessingEvaluator(model) as evaluator:
#     results = evaluator.optimize(nfe=12000, searchover='levers', reference=reference,
#                                  convergence = convergence, epsilons=epsilons)
    
# save_results(results, 'results/multi-scenario-mordm/pf1/msmordm_pf3_step1.tar.gz')
# print(time.time()-starttime)

# %% [markdown]
# ### Step 2: Perform experiments given optimized levers from one reference scenario.

# %%
results = load_results('results/multi-scenario-mordm/pf3/msmordm_pf3_step1.tar.gz')
# Out:
# [MainProcess/INFO] results loaded succesfully from C:\Users\Leonardo\OneDrive\Documents\TU_Delft\EPA_Year1\EPA1361\assignments\epa1361_open\final assignment\final\Final Results\results\multi-scenario-mordm\pf3\msmordm_pf3_step1.tar.gz

# %%
outcomes, convergence = results

# %%
fig, ax = plt.subplots(ncols=1, sharex=True, figsize=(5,3), dpi=100)
convergence = pd.DataFrame(convergence)
ax.plot(convergence.nfe, convergence.epsilon_progress)
ax.set_ylabel('$\epsilon$-progress')
ax.set_xlabel('number of function evaluations')
ax.set_title("Convergence: Reference Scenario")
# Out:
# Text(0.5, 1.0, 'Convergence: Reference Scenario')

# %%
limits = parcoords.get_limits(outcomes[model_outcomes])
formatter = dict(zip(limits.columns, ['.0f']*(len(limits.columns))))
fig = plt.figure(figsize=(30,10), dpi=500)
paraxes = parcoords.ParallelAxes(limits, formatter=formatter,fontsize=11)
for i in range(24):
    paraxes.plot(outcomes[outcomes.index==i][model_outcomes])

plt.show()

# %%
outcomes_cols = []
outcome_of_interest = "Deaths"
for i in outcomes.columns:
    if outcome_of_interest in i:
        outcomes_cols.append(i)
outcomes["Total " + str(outcome_of_interest)] = outcomes[outcomes_cols].sum(axis=1)

# %%
if len(outcomes) > 10:
    if len(outcomes[outcomes['RfR Total Costs'] != 0]) > 7:
        outcomes = outcomes[outcomes['RfR Total Costs'] != 0]
        
if len(outcomes) > 10:
    if len(outcomes[outcomes["Total Deaths"] < np.percentile(outcomes["Total Deaths"], 5)]) > 7:
        outcomes = outcomes[outcomes["Total Deaths"] < np.percentile(outcomes["Total Deaths"], 5)]

if len(outcomes) > 10:
    if len(outcomes[outcomes['Expected Evacuation Costs']< np.percentile(outcomes["Expected Evacuation Costs"], 15)]) > 7:
        outcomes = outcomes[outcomes['Expected Evacuation Costs']< np.percentile(outcomes["Expected Evacuation Costs"], 15)]

# %%
policy = outcomes[model_levers]

policies = []

for i,policy in policy.iterrows():
    policies.append(Policy(str(i),**policy.to_dict()))

# %%
# starttime = time.time()

# with MultiprocessingEvaluator(model) as evaluator:
#     results_step2 = evaluator.perform_experiments(scenarios=2000, policies=policies)

# save_results(results_step2, 'results/multi-scenario-mordm/pf1/msmordm_pf1_step2.tar.gz')
# print(time.time()-starttime)

# %% [markdown]
# ### Step 3: Scenario discovery for selecting multiple scenarios of interest.

# %%
results_step2 = load_results("results/multi-scenario-mordm/pf3/msmordm_pf3_step2.tar.gz")
# Out:
# [MainProcess/INFO] results loaded succesfully from C:\Users\jryap\Desktop\Final Results\results\multi-scenario-mordm\pf3\msmordm_pf3_step2.tar.gz

# %%
experiments, outcomes = results_step2
outcomes_df = pd.DataFrame(outcomes)

# %% [markdown]
# #### Scenario Discovery using PRIM

# %%
x = experiments[model_uncertainties]
y = outcomes_df.iloc[:,3] > np.percentile(outcomes_df.iloc[:,3], 80)
prim_alg = prim.Prim(x, y, threshold=0.7, peel_alpha=0.1)
box = prim_alg.find_box()
# Out:
# [MainProcess/INFO] 68000 points remaining, containing 13600 cases of interest
# [MainProcess/INFO] mean: 0.9019607843137255, mass: 0.051, coverage: 0.23, density: 0.9019607843137255 restricted_dimensions: 2

# %%
box.show_tradeoff()
plt.show()

# %%
box.inspect(23)
# Out:
# coverage       0.355
# density     0.816092
# id                23
# mass           0.087
# mean        0.816092
# res_dim            2
# Name: 23, dtype: object
#
#              box 23
#                 min       max                      qp values
# A.2_pfail  0.000006  0.097013                    [-1.0, 0.0]
# A.1_pfail  0.084512  0.999688  [1.395613021320935e-05, -1.0]

# %%
box.select(23)

# %%
selected_experiments = experiments.iloc[box.yi]
selected_outcomes = {k:v[box.yi] for k,v in outcomes_df.items()}

# %%
selected_experiments = selected_experiments.join(pd.DataFrame(selected_outcomes))

# %% [markdown]
# From the selected box of scenarios, we again filter the scenarios, and select only scenarios that yielded the worst performance for each of the three indicators.

# %%
del selected_experiments["policy"]
del selected_experiments["model"]

# %%
scenarios = []

# get scenarios for each worst-performing indicator
for i in range(len(outcomes_df.columns)):
    scenarios.append(selected_experiments.sort_values(by=outcomes_df.columns[i]).reset_index()["scenario"][0])

# %%
experiments_unique = selected_experiments.drop_duplicates(subset=["scenario"], keep="first")
experiments_unique = experiments_unique.loc[experiments_unique['scenario'].isin(scenarios) == True]
experiments_unique = experiments_unique.iloc[:, :-1]

# %%
reference = []

for i,uncertainty in experiments_unique.iterrows():
    reference.append(Scenario(str(i),**uncertainty.to_dict()))

# %% [markdown]
# Thus, we have four reference scenarios, under which we search for optimized levers.

# %%
# outcomes = []

# starttime = time.time()

# for i in range(len(reference)):
#     with MultiprocessingEvaluator(model) as evaluator:
#         results_step3 = evaluator.optimize(searchover='levers', nfe=12000, epsilons=epsilons, 
#                                      convergence=convergence, reference=reference[i])
#     save_results(results_step3,
#                  "results/multi-scenario-mordm/pf3/msmordm_pf3_step3_ref{}.tar.gz".format(i))
#     outcomes.append(results_step3)

# print(time.time()-starttime)

# %% [markdown]
# ### Step 4:

# %%
results1 = load_results('results/multi-scenario-mordm/pf3/msmordm_pf3_step3_ref0.tar.gz')
results2 = load_results('results/multi-scenario-mordm/pf3/msmordm_pf3_step3_ref1.tar.gz')
results3 = load_results('results/multi-scenario-mordm/pf3/msmordm_pf3_step3_ref2.tar.gz')
results4 = load_results('results/multi-scenario-mordm/pf3/msmordm_pf3_step3_ref3.tar.gz')
# Out:
# [MainProcess/INFO] results loaded succesfully from C:\Users\jryap\Desktop\Final Results\results\multi-scenario-mordm\pf3\msmordm_pf3_step3_ref0.tar.gz
# [MainProcess/INFO] results loaded succesfully from C:\Users\jryap\Desktop\Final Results\results\multi-scenario-mordm\pf3\msmordm_pf3_step3_ref1.tar.gz
# [MainProcess/INFO] results loaded succesfully from C:\Users\jryap\Desktop\Final Results\results\multi-scenario-mordm\pf3\msmordm_pf3_step3_ref2.tar.gz
# [MainProcess/INFO] results loaded succesfully from C:\Users\jryap\Desktop\Final Results\results\multi-scenario-mordm\pf3\msmordm_pf3_step3_ref3.tar.gz

# %%
outcomes1, convergence1 = results1
outcomes2, convergence2 = results2
outcomes3, convergence3 = results3
outcomes4, convergence4 = results4
outcomes = [outcomes1, outcomes2, outcomes3, outcomes4]
print(len(outcomes1), len(outcomes2), len(outcomes3), len(outcomes4))
# Out:
# 315 725 976 322

# %% [markdown]
# First, we evaluate the convergence of the optimization runs.

# %%
convergences = [pd.DataFrame(convergence1), pd.DataFrame(convergence2),
                pd.DataFrame(convergence3), pd.DataFrame(convergence4)]
fig, ax = plt.subplots(ncols=len(convergences), sharex=True, figsize=(14,3))

for i in range(len(convergences)):
    ax[i].plot(convergences[i].nfe, convergences[i].epsilon_progress)
    ax[i].set_ylabel('$\epsilon$-progress')
    ax[i].set_xlabel('number of function evaluations')
    ax[i].set_title("Convergence: Reference Scenario {}".format(i))

# %% [markdown]
# Then, we take a look at the tradeoffs between each policies with a parallel coordinates plot.

# %% [markdown]
# We sum up all policies for RfR. If this sum is equal to zero, this indicates that RfR is not implemented anywhere.

# %%
outcomes_cols = []
outcome_of_interest = "Deaths"
for j in outcomes:
    for i in j.columns:
        if outcome_of_interest in i:
            outcomes_cols.append(i)
    j["Total " + str(outcome_of_interest)] = j[outcomes_cols].sum(axis=1)

# %% [markdown]
# We filter and remove policies that exceed the 10th percentile of Total Deaths and RfR Total Costs. This leaves us with 24 policies.

# %%
outcomes1 = outcomes1[outcomes1["Total Deaths"] < np.percentile(outcomes1["Total Deaths"], 10)]
outcomes1 = outcomes1[outcomes1["RfR Total Costs"] < np.percentile(outcomes1["RfR Total Costs"], 10)]
outcomes2 = outcomes2[outcomes2["Total Deaths"] < np.percentile(outcomes2["Total Deaths"], 10)]
outcomes2 = outcomes2[outcomes2["RfR Total Costs"] < np.percentile(outcomes2["RfR Total Costs"], 10)]
outcomes3 = outcomes3[outcomes3["Total Deaths"] < np.percentile(outcomes3["Total Deaths"], 10)]
outcomes3 = outcomes3[outcomes3["RfR Total Costs"] < np.percentile(outcomes3["RfR Total Costs"], 10)]
outcomes4 = outcomes4[outcomes4["RfR Total Costs"] < np.percentile(outcomes4["RfR Total Costs"], 10)]

# %%
print(len(outcomes1), len(outcomes2), len(outcomes3), len(outcomes4))
# Out:
# 3 7 10 4

# %%
filtered_policies = pd.concat([outcomes1, outcomes2, outcomes3, outcomes4])

# %%
chosen_ones = list(filtered_policies.index)

# %%
col_names = []
for i in limits.columns:
    if "Costs" in i:
        col_names.append(i)

# %%
a = outcomes1.copy()
b = outcomes2.copy()
c = outcomes3.copy()
d = outcomes4.copy()

# %%
a[col_names] = a[col_names]/1e8
b[col_names] = b[col_names]/1e8
c[col_names] = c[col_names]/1e8
d[col_names] = d[col_names]/1e8

# %%
all_dfs = outcomes.copy()
all_dfs[col_names] = all_dfs[col_names]/1e8

# %%
outcomes_concat = pd.concat([a,b,c,d])
limits = parcoords.get_limits(all_dfs[model_outcomes])
formatter = dict(zip(limits.columns, ['.2f']*(len(limits.columns))))
fig = plt.figure(figsize=(30,10), dpi=400)
paraxes = parcoords.ParallelAxes(limits, formatter=formatter, fontsize=10)
paraxes.plot(all_dfs[model_outcomes], color="lightgrey", label="Other Policies")
paraxes.plot(a[model_outcomes], color="darkgreen", label="Chosen Policies")
paraxes.plot(b[model_outcomes], color="darkgreen")
paraxes.plot(c[model_outcomes], color="darkgreen")
paraxes.plot(d[model_outcomes], color="darkgreen")
paraxes.legend()
plt.show()

# %%
policy = filtered_policies[model_levers]
policies = []

for i,policy in policy.iterrows():
    policies.append(Policy(str(i),**policy.to_dict()))

# %%
len(policies)
# Out:
# 24

# %%
# starttime = time.time()
# with MultiprocessingEvaluator(model) as evaluator:
#     results_step4 = evaluator.perform_experiments(scenarios=8000, policies=policies,
#                                                   uncertainty_sampling="lhs")

# save_results(results_step4, "results/multi-scenario-mordm/pf3/msmordm_pf3_step4.tar.gz")
# print(time.time()-starttime)

# %% [markdown]
# ## 2.0 Analysis of Results
# ### 2.1 Overview of results

# %%
results_step4 = load_results("results/multi-scenario-mordm/pf3/msmordm_pf3_step4.tar.gz")
results_step4_1 = load_results("results/multi-scenario-mordm/pf3/msmordm_pf3_step4_1.tar.gz")
# Out:
# [MainProcess/INFO] results loaded succesfully from C:\Users\Leonardo\OneDrive\Documents\TU_Delft\EPA_Year1\EPA1361\assignments\epa1361_open\final assignment\final\Final Results\results\multi-scenario-mordm\pf3\msmordm_pf3_step4.tar.gz
# [MainProcess/INFO] results loaded succesfully from C:\Users\Leonardo\OneDrive\Documents\TU_Delft\EPA_Year1\EPA1361\assignments\epa1361_open\final assignment\final\Final Results\results\multi-scenario-mordm\pf3\msmordm_pf3_step4_1.tar.gz

# %%
experiments1, outcomes1 = results_step4
experiments2, outcomes2 = results_step4_1
experiments = pd.concat([experiments1, experiments2])
outcomes = pd.concat([pd.DataFrame(outcomes1), pd.DataFrame(outcomes2)])

# %% [markdown]
# We use a parallel coordinates plot to generate an overview of the selected optimized policies.

# %%
policies_0 = [col for col in experiments[model_levers].columns if ' 0' in col]
policies_1 = [col for col in experiments[model_levers].columns if ' 1' in col]
policies_2 = [col for col in experiments[model_levers].columns if ' 2' in col]

experiments = experiments[model_levers].drop_duplicates()
time0 = experiments[policies_0]
time1 = experiments[policies_1]
time2 = experiments[policies_2]

times = [time0, time1, time2]

for i in range(len(times)):
    times[i]["Time Step"] = i
    times[i].columns = times[i].columns.str.replace(' {}'.format(i), '')
    times[i]["EWS Days to Threat"] = experiments["EWS_DaysToThreat"]
    times[i].index = list(range(len(time0)))
    
policies = pd.concat([time0, time1, time2])
limits = parcoords.get_limits(policies)
del limits["Time Step"]
# Out:
# C:\Users\Leonardo\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\Leonardo\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app

# %%
fig = plt.figure(figsize=(15,20), dpi=300)
formatter = dict(zip(limits.columns, ['.0f']*(len(limits.columns))))
paraxes = parcoords.ParallelAxes(limits, formatter=formatter,fontsize=11, rot=90)
paraxes.plot(time0, color=sns.color_palette("dark")[0], label='Time Step 0')
paraxes.plot(time1, color=sns.color_palette("dark")[3], label='Time Step 1')
paraxes.plot(time2, color=sns.color_palette("dark")[2], label='Time Step 2')
paraxes.legend()
plt.show()

# %%
experiments1, outcomes1 = results_step4
experiments2, outcomes2 = results_step4_1
experiments = pd.concat([experiments1, experiments2])
outcomes = pd.concat([pd.DataFrame(outcomes1), pd.DataFrame(outcomes2)])

# %% [markdown]
# We use a parallel coordinates plot to generate an overview of the tradeoffs in outcomes over all policies (3 at a time) and scenarios.

# %%
experiments = experiments.join(outcomes)

# %%
limits = parcoords.get_limits(experiments[model_outcomes])
formatter = dict(zip(limits.columns, ['.2f']*(len(limits.columns))))

fig = plt.figure(figsize=(20,10), dpi=300)
paraxes = parcoords.ParallelAxes(limits, formatter=formatter,fontsize=11)
paraxes.plot(experiments[model_outcomes], color=sns.color_palette("dark")[i])
paraxes.legend()
plt.show()

# %% [markdown]
# ### 2.2 Robustness Metrics
#
# We calculated the signal-to-noise ratio and the maximum regret for the policy outcomes in order to evaluate the robustness of the policies.

# %%
model, steps = get_model_for_problem_formulation(3)
experiments, outcomes = results_step4

# %%
def s_to_n(data, direction):
    mean = np.mean(data)
    std = np.std(data)
    
    if direction==ScalarOutcome.MAXIMIZE:
        return mean/std
    else:
        return mean*std

def calculate_regret(data, best):
    return np.abs(best-data)

# %%
overall_scores = {}
for policy in np.unique(experiments['policy']):
    scores = {}
    
    logical = experiments['policy']==policy
    
    for outcome in model.outcomes:
        value  = outcomes[outcome.name][logical]
        sn_ratio = s_to_n(value, outcome.kind)
        scores[outcome.name] = sn_ratio
    overall_scores[policy] = scores
scores = pd.DataFrame.from_dict(overall_scores).T

# %% [markdown]
# Parallel coordinates plot to evaluate the signal-to-noise ratio for each of the policies.

# %%
limits = parcoords.get_limits(scores)
limits.loc[0, outcomes.keys()] = 0

fig = plt.figure(figsize=(10,20), dpi=500)
paraxes = parcoords.ParallelAxes(limits, rot=0, fontsize=11)
paraxes.plot(scores)
plt.show()
# Out:
# C:\Users\Leonardo\Anaconda3\lib\site-packages\ema_workbench\analysis\parcoords.py:198: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   plt.tight_layout(h_pad=0, w_pad=0)

# %%
overall_regret = {}
max_regret = {}
for outcome in model.outcomes:
    policy_column = experiments['policy']
    
    # Create a DataFrame with all the relevent information
    # i.e., policy, scenario_id, and scores
    data = pd.DataFrame({outcome.name: outcomes[outcome.name], 
                         "policy":experiments['policy'],
                         "scenario":experiments['scenario']})
    
    data = data.pivot(index='scenario', columns='policy')
    
    # Flatten the resulting hierarchical index resulting from pivoting
    data.columns = data.columns.get_level_values(1)
    
    # we need to control the broadcasting. max returns a 1d vector across scenario id. By passing
    # np.newaxis we ensure that the shape is the same as the data next we take the absolute value
    # basically we take the difference of the maximum acrossthe row and the actual values in the row
    
    outcome_regret = (data.max(axis=1)[:, np.newaxis] - data).abs()
    overall_regret[outcome.name] = outcome_regret
    max_regret[outcome.name] = outcome_regret.max()
    
max_regret = pd.DataFrame(max_regret)
max_regret['Policy'] = "Policy " + max_regret.reset_index()['policy'].astype('str').values
max_regret.set_index('Policy', inplace = True)

# %% [markdown]
# Generate a heatmap to show the maximum regret for each policy on each outcome.

# %%
import plotly
import plotly.graph_objs as go

heat = go.Heatmap(z=max_regret/max_regret.max(), x=max_regret.columns.tolist(), 
              y=max_regret.reset_index()['Policy'], xgap=10, ygap=10,
              colorscale = plotly.colors.sequential.Reds)

plot_data = [heat]

layout = go.Layout(title = 'Maximum Regret',
                   width=650, height=600,
                   xaxis_showgrid=False,
                   yaxis_showgrid=False,
                   template = "plotly_white", )

fig=go.Figure(data=[heat], layout=layout) 
fig.show()
fig.write_image(f"figures/msmordm_pf3_step4_max_regret_heat.png", scale = 3)

# %%
data = max_regret.copy()
fig = plt.figure(figsize=(20,10), dpi=300)
limits = parcoords.get_limits(data)
limits.loc[0, max_regret.columns] = 0

paraxes = parcoords.ParallelAxes(limits, fontsize=11, rot=0)
for i, (index, row) in enumerate(data.iterrows()):
    paraxes.plot(row.to_frame().T, label=str(index))
paraxes.legend()
    
plt.show()
# Out:
# C:\Users\Leonardo\Anaconda3\lib\site-packages\ema_workbench\analysis\parcoords.py:198: UserWarning:
#
# Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#
# C:\Users\Leonardo\Anaconda3\lib\site-packages\ema_workbench\analysis\parcoords.py:261: UserWarning:
#
# Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations

# %%
from collections import defaultdict

policy_regret = defaultdict(dict)
for key, value in overall_regret.items():
    for policy in value:
        policy_regret[policy][key] = value[policy]

# %%
# accross all plots
fig, axes = plt.subplots(ncols=2, nrows=2, figsize=(10,10), 
                         sharey=True, sharex=True)

# to ensure easy iteration over the axes grid, we turn it
# into a list. Because there are four plots, I hard coded
# this. 
axes = [axes[0,0], axes[0,1],
        axes[1,0],]

# zip allows us to zip together the list of axes and the list of 
# key value pairs return by items. If we iterate over this
# it returns a tuple of length 2. The first item is the ax
# the second items is the key value pair.
for ax, (policy, regret) in zip(axes, policy_regret.items()):
    data = pd.DataFrame(regret)

    # we need to scale the regret to ensure fair visual
    # comparison. We can do that by divding by the maximum regret
    data = data/max_regret.max(axis=0)
    sns.boxplot(data=data, ax=ax)
    
    # removes top and left hand black outline of axes
    sns.despine()
    
    # ensure we know which policy the figure is for
    ax.set_title(str(policy))
    
#     ax.text(size = 8)
plt.show()
plt.savefig(f"figures/msmordm_pf3_step4_max_regret_dist.png", dpi=300)
